# %%
from virtual_accelerator.models.facet2 import get_facet_bmad_model

model = get_facet_bmad_model(
    track_beam=True,
    start_element="L0AFEND",
    end_element="PR10571",
)

# %%
variable_names = list(model.supported_variables.keys())
print(f"Supported variables: {len(variable_names)}")
print("Example variable names:")
print(variable_names[:10])

# %% [markdown]
# ## Predictions at elements

# %%
import matplotlib.pyplot as plt

out = model.get(["s_ele", "a.beta", "b.beta", "e_tot"])
plt.plot(out["s_ele"], out["e_tot"] / 1e6, label="b")
plt.ylabel("Total energy (MeV)")
plt.xlabel("s (m)")

plt.figure()
plt.plot(out["s_ele"], out["a.beta"], label="a.beta")
plt.plot(out["s_ele"], out["b.beta"], label="b.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()

# %% [markdown]
# ## Predictions using comb

# %%
import matplotlib.pyplot as plt

out = model.get(["s", "x.beta", "y.beta"])

plt.figure()
plt.plot(out["s"], out["x.beta"], label="x.beta")
plt.plot(out["s"], out["y.beta"], label="y.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()

# %% [markdown]
# ## Staged FACET-II model

# %%
from virtual_accelerator.models.facet2 import get_facet_staged_model

staged_model = get_facet_staged_model(
    surrogate_inputs="machine", n_particles=10000, end_element="PR10711"
)

# %%
import matplotlib.pyplot as plt

out = staged_model.get(["s", "x.beta", "y.beta", "s_ele", "a.beta", "b.beta"])
plt.plot(out["s"], out["x.beta"], label="tracked x.beta")
plt.plot(out["s"], out["y.beta"], label="tracked y.beta")
plt.plot(out["s_ele"], out["a.beta"], "--", label="design a.beta")
plt.plot(out["s_ele"], out["b.beta"], "--", label="design b.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()

# %% [markdown]
# ## Staged model with Impact

# %%
import matplotlib.pyplot as plt
from virtual_accelerator.models.facet2 import (
    get_facet_impact_model,
    get_facet_bmad_model,
)
from lume.staged_model import StagedModel


impact_model = get_facet_impact_model(n_particles=1000, end_element="PR10241")

facet_bmad_model = get_facet_bmad_model(
    start_element="PR10241",
    end_element="TD11",
    track_beam=True,
)

staged_model = StagedModel([impact_model, facet_bmad_model])
# Out:
# Element type solrf for element GUNF not found in variable configuration mapping. Skipping.
# Element type solrf for element SOL10111 not found in variable configuration mapping. Skipping.
# Element type Multipole for element SQ10122 not found in variable configuration mapping. Skipping.
# Element type Multipole for element CQ10121 not found in variable configuration mapping. Skipping.
# Element type Lcavity for element L0AF not found in variable configuration mapping. Skipping.
# Element type Lcavity for element L0BF not found in variable configuration mapping. Skipping.
# Error getting element type for UM10466: Command: 'pipe ele:head UM10466|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head UM10466|model": Multiple matches to element: UM10466. Defaulting to 'Unknown'.
# Element type Unknown for element UM10466 not found in variable configuration mapping. Skipping.
# Element type Monitor for element BZ10596 not found in variable configuration mapping. Skipping.
# Error getting element type for K11_1: Command: 'pipe ele:head K11_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_1|model": Cannot locate element: K11_1. Defaulting to 'Unknown'.
# Element K11_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAQ1: Command: 'pipe ele:head DAQ1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ1|model": Multiple matches to element: DAQ1. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ1 not found in variable configuration mapping. Skipping.
# Error getting element type for DAQ2: Command: 'pipe ele:head DAQ2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ2|model": Multiple matches to element: DAQ2. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ2 not found in variable configuration mapping. Skipping.
# Error getting element type for K11_2: Command: 'pipe ele:head K11_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_2|model": Cannot locate element: K11_2. Defaulting to 'Unknown'.
# Element K11_2 not found in Tao lattice. Skipping variable generation for this element.
# Element type Lcavity for element L1XF not found in variable configuration mapping. Skipping.
# Screen PR11316 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Screen PR11334 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Screen PR11335 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Screen PR11342 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type RCollimator for element CE11334 not found in variable configuration mapping. Skipping.
# Screen PR11357 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type Monitor for element BL11356 not found in variable configuration mapping. Skipping.
# Screen PR11375 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type Monitor for element TD11390 not found in variable configuration mapping. Skipping.
# Error getting element type for K11_4: Command: 'pipe ele:head K11_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_4|model": Cannot locate element: K11_4. Defaulting to 'Unknown'.
# Element K11_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAA7: Command: 'pipe ele:head DAA7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7|model": Multiple matches to element: DAA7. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7 not found in variable configuration mapping. Skipping.
# Error getting element type for DAA7A: Command: 'pipe ele:head DAA7A|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7A|model": Multiple matches to element: DAA7A. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7A not found in variable configuration mapping. Skipping.
# Error getting element type for DAA7B: Command: 'pipe ele:head DAA7B|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7B|model": Multiple matches to element: DAA7B. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7B not found in variable configuration mapping. Skipping.
# Error getting element type for DAA7C: Command: 'pipe ele:head DAA7C|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7C|model": Multiple matches to element: DAA7C. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7C not found in variable configuration mapping. Skipping.
# Error getting element type for K11_5: Command: 'pipe ele:head K11_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_5|model": Cannot locate element: K11_5. Defaulting to 'Unknown'.
# Element K11_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K11_6: Command: 'pipe ele:head K11_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_6|model": Cannot locate element: K11_6. Defaulting to 'Unknown'.
# Element K11_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAA7D: Command: 'pipe ele:head DAA7D|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7D|model": Multiple matches to element: DAA7D. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7D not found in variable configuration mapping. Skipping.
# Error getting element type for DAA7E: Command: 'pipe ele:head DAA7E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7E|model": Multiple matches to element: DAA7E. Defaulting to 'Unknown'.
# Element type Unknown for element DAA7E not found in variable configuration mapping. Skipping.
# Error getting element type for K11_7: Command: 'pipe ele:head K11_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_7|model": Cannot locate element: K11_7. Defaulting to 'Unknown'.
# Element K11_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K11_8: Command: 'pipe ele:head K11_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_8|model": Cannot locate element: K11_8. Defaulting to 'Unknown'.
# Element K11_8 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAQ3: Command: 'pipe ele:head DAQ3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ3|model": Multiple matches to element: DAQ3. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ3 not found in variable configuration mapping. Skipping.
# Error getting element type for K12_1: Command: 'pipe ele:head K12_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_1|model": Cannot locate element: K12_1. Defaulting to 'Unknown'.
# Element K12_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_2: Command: 'pipe ele:head K12_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_2|model": Cannot locate element: K12_2. Defaulting to 'Unknown'.
# Element K12_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_3: Command: 'pipe ele:head K12_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_3|model": Cannot locate element: K12_3. Defaulting to 'Unknown'.
# Element K12_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_4: Command: 'pipe ele:head K12_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_4|model": Cannot locate element: K12_4. Defaulting to 'Unknown'.
# Element K12_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_5: Command: 'pipe ele:head K12_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_5|model": Cannot locate element: K12_5. Defaulting to 'Unknown'.
# Element K12_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_6: Command: 'pipe ele:head K12_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_6|model": Cannot locate element: K12_6. Defaulting to 'Unknown'.
# Element K12_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_7: Command: 'pipe ele:head K12_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_7|model": Cannot locate element: K12_7. Defaulting to 'Unknown'.
# Element K12_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K12_8: Command: 'pipe ele:head K12_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_8|model": Cannot locate element: K12_8. Defaulting to 'Unknown'.
# Element K12_8 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAQ4: Command: 'pipe ele:head DAQ4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ4|model": Multiple matches to element: DAQ4. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ4 not found in variable configuration mapping. Skipping.
# Error getting element type for K13_1: Command: 'pipe ele:head K13_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_1|model": Cannot locate element: K13_1. Defaulting to 'Unknown'.
# Element K13_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_2: Command: 'pipe ele:head K13_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_2|model": Cannot locate element: K13_2. Defaulting to 'Unknown'.
# Element K13_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_3: Command: 'pipe ele:head K13_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_3|model": Cannot locate element: K13_3. Defaulting to 'Unknown'.
# Element K13_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_4: Command: 'pipe ele:head K13_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_4|model": Cannot locate element: K13_4. Defaulting to 'Unknown'.
# Element K13_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_5: Command: 'pipe ele:head K13_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_5|model": Cannot locate element: K13_5. Defaulting to 'Unknown'.
# Element K13_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_6: Command: 'pipe ele:head K13_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_6|model": Cannot locate element: K13_6. Defaulting to 'Unknown'.
# Element K13_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_7: Command: 'pipe ele:head K13_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_7|model": Cannot locate element: K13_7. Defaulting to 'Unknown'.
# Element K13_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K13_8: Command: 'pipe ele:head K13_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_8|model": Cannot locate element: K13_8. Defaulting to 'Unknown'.
# Element K13_8 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_1: Command: 'pipe ele:head K14_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_1|model": Cannot locate element: K14_1. Defaulting to 'Unknown'.
# Element K14_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_2: Command: 'pipe ele:head K14_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_2|model": Cannot locate element: K14_2. Defaulting to 'Unknown'.
# Element K14_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_3: Command: 'pipe ele:head K14_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_3|model": Cannot locate element: K14_3. Defaulting to 'Unknown'.
# Element K14_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_4: Command: 'pipe ele:head K14_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_4|model": Cannot locate element: K14_4. Defaulting to 'Unknown'.
# Element K14_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_5: Command: 'pipe ele:head K14_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_5|model": Cannot locate element: K14_5. Defaulting to 'Unknown'.
# Element K14_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K14_6: Command: 'pipe ele:head K14_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_6|model": Cannot locate element: K14_6. Defaulting to 'Unknown'.
# Element K14_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for LI14TERM: Command: 'pipe ele:head LI14TERM|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head LI14TERM|model": Multiple matches to element: LI14TERM. Defaulting to 'Unknown'.
# Element type Unknown for element LI14TERM not found in variable configuration mapping. Skipping.
# Screen PR14803 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type RCollimator for element CE14815 not found in variable configuration mapping. Skipping.
# Element type Monitor for element BL14888 not found in variable configuration mapping. Skipping.
# Screen PR14892 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Error getting element type for K15_1: Command: 'pipe ele:head K15_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_1|model": Cannot locate element: K15_1. Defaulting to 'Unknown'.
# Element K15_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_2: Command: 'pipe ele:head K15_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_2|model": Cannot locate element: K15_2. Defaulting to 'Unknown'.
# Element K15_2 not found in Tao lattice. Skipping variable generation for this element.
# Element type Lcavity for element TCY15280 not found in variable configuration mapping. Skipping.
# Error getting element type for K15_3: Command: 'pipe ele:head K15_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_3|model": Cannot locate element: K15_3. Defaulting to 'Unknown'.
# Element K15_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_4: Command: 'pipe ele:head K15_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_4|model": Cannot locate element: K15_4. Defaulting to 'Unknown'.
# Element K15_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_5: Command: 'pipe ele:head K15_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_5|model": Cannot locate element: K15_5. Defaulting to 'Unknown'.
# Element K15_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_6: Command: 'pipe ele:head K15_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_6|model": Cannot locate element: K15_6. Defaulting to 'Unknown'.
# Element K15_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_7: Command: 'pipe ele:head K15_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_7|model": Cannot locate element: K15_7. Defaulting to 'Unknown'.
# Element K15_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K15_8: Command: 'pipe ele:head K15_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_8|model": Cannot locate element: K15_8. Defaulting to 'Unknown'.
# Element K15_8 not found in Tao lattice. Skipping variable generation for this element.
# Screen PR15944 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Error getting element type for K16_1: Command: 'pipe ele:head K16_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_1|model": Cannot locate element: K16_1. Defaulting to 'Unknown'.
# Element K16_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_2: Command: 'pipe ele:head K16_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_2|model": Cannot locate element: K16_2. Defaulting to 'Unknown'.
# Element K16_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_3: Command: 'pipe ele:head K16_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_3|model": Cannot locate element: K16_3. Defaulting to 'Unknown'.
# Element K16_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_4: Command: 'pipe ele:head K16_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_4|model": Cannot locate element: K16_4. Defaulting to 'Unknown'.
# Element K16_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_5: Command: 'pipe ele:head K16_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_5|model": Cannot locate element: K16_5. Defaulting to 'Unknown'.
# Element K16_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_6: Command: 'pipe ele:head K16_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_6|model": Cannot locate element: K16_6. Defaulting to 'Unknown'.
# Element K16_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_7: Command: 'pipe ele:head K16_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_7|model": Cannot locate element: K16_7. Defaulting to 'Unknown'.
# Element K16_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K16_8: Command: 'pipe ele:head K16_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_8|model": Cannot locate element: K16_8. Defaulting to 'Unknown'.
# Element K16_8 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_1: Command: 'pipe ele:head K17_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_1|model": Cannot locate element: K17_1. Defaulting to 'Unknown'.
# Element K17_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_2: Command: 'pipe ele:head K17_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_2|model": Cannot locate element: K17_2. Defaulting to 'Unknown'.
# Element K17_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_3: Command: 'pipe ele:head K17_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_3|model": Cannot locate element: K17_3. Defaulting to 'Unknown'.
# Element K17_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_4: Command: 'pipe ele:head K17_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_4|model": Cannot locate element: K17_4. Defaulting to 'Unknown'.
# Element K17_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_5: Command: 'pipe ele:head K17_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_5|model": Cannot locate element: K17_5. Defaulting to 'Unknown'.
# Element K17_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_6: Command: 'pipe ele:head K17_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_6|model": Cannot locate element: K17_6. Defaulting to 'Unknown'.
# Element K17_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_7: Command: 'pipe ele:head K17_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_7|model": Cannot locate element: K17_7. Defaulting to 'Unknown'.
# Element K17_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K17_8: Command: 'pipe ele:head K17_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_8|model": Cannot locate element: K17_8. Defaulting to 'Unknown'.
# Element K17_8 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_1: Command: 'pipe ele:head K18_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_1|model": Cannot locate element: K18_1. Defaulting to 'Unknown'.
# Element K18_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_2: Command: 'pipe ele:head K18_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_2|model": Cannot locate element: K18_2. Defaulting to 'Unknown'.
# Element K18_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_3: Command: 'pipe ele:head K18_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_3|model": Cannot locate element: K18_3. Defaulting to 'Unknown'.
# Element K18_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_4: Command: 'pipe ele:head K18_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_4|model": Cannot locate element: K18_4. Defaulting to 'Unknown'.
# Element K18_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_5: Command: 'pipe ele:head K18_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_5|model": Cannot locate element: K18_5. Defaulting to 'Unknown'.
# Element K18_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_6: Command: 'pipe ele:head K18_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_6|model": Cannot locate element: K18_6. Defaulting to 'Unknown'.
# Element K18_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_7: Command: 'pipe ele:head K18_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_7|model": Cannot locate element: K18_7. Defaulting to 'Unknown'.
# Element K18_7 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K18_8: Command: 'pipe ele:head K18_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_8|model": Cannot locate element: K18_8. Defaulting to 'Unknown'.
# Element K18_8 not found in Tao lattice. Skipping variable generation for this element.
# Element type Monitor for element BL18900 not found in variable configuration mapping. Skipping.
# Element type RCollimator for element CX18960 not found in variable configuration mapping. Skipping.
# Element type RCollimator for element CY18960 not found in variable configuration mapping. Skipping.
# Error getting element type for K19_1: Command: 'pipe ele:head K19_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_1|model": Cannot locate element: K19_1. Defaulting to 'Unknown'.
# Element K19_1 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DAQ5A: Command: 'pipe ele:head DAQ5A|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ5A|model": Multiple matches to element: DAQ5A. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ5A not found in variable configuration mapping. Skipping.
# Error getting element type for DAQ5B: Command: 'pipe ele:head DAQ5B|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ5B|model": Multiple matches to element: DAQ5B. Defaulting to 'Unknown'.
# Element type Unknown for element DAQ5B not found in variable configuration mapping. Skipping.
# Error getting element type for K19_2: Command: 'pipe ele:head K19_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_2|model": Cannot locate element: K19_2. Defaulting to 'Unknown'.
# Element K19_2 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K19_3: Command: 'pipe ele:head K19_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_3|model": Cannot locate element: K19_3. Defaulting to 'Unknown'.
# Element K19_3 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K19_4: Command: 'pipe ele:head K19_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_4|model": Cannot locate element: K19_4. Defaulting to 'Unknown'.
# Element K19_4 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for DBKY170: Command: 'pipe ele:head DBKY170|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBKY170|model": Multiple matches to element: DBKY170. Defaulting to 'Unknown'.
# Element type Unknown for element DBKY170 not found in variable configuration mapping. Skipping.
# Error getting element type for K19_5: Command: 'pipe ele:head K19_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_5|model": Cannot locate element: K19_5. Defaulting to 'Unknown'.
# Element K19_5 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for K19_6: Command: 'pipe ele:head K19_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_6|model": Cannot locate element: K19_6. Defaulting to 'Unknown'.
# Element K19_6 not found in Tao lattice. Skipping variable generation for this element.
# Error getting element type for D10: Command: 'pipe ele:head D10|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head D10|model": Multiple matches to element: D10. Defaulting to 'Unknown'.
# Element type Unknown for element D10 not found in variable configuration mapping. Skipping.
# Element type Lcavity for element K19_8A1 not found in variable configuration mapping. Skipping.
# Element type Lcavity for element K19_8A2 not found in variable configuration mapping. Skipping.
# Element type Lcavity for element K19_8A3 not found in variable configuration mapping. Skipping.
# Element type Patch for element PATCH_BC20 not found in variable configuration mapping. Skipping.
# Element type Monitor for element PMON not found in variable configuration mapping. Skipping.
# Element type Monitor for element M1E not found in variable configuration mapping. Skipping.
# Element type RCollimator for element CN2069 not found in variable configuration mapping. Skipping.
# Element type RCollimator for element CX2085 not found in variable configuration mapping. Skipping.
# Error getting element type for DYC1E: Command: 'pipe ele:head DYC1E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC1E|model": Multiple matches to element: DYC1E. Defaulting to 'Unknown'.
# Element type Unknown for element DYC1E not found in variable configuration mapping. Skipping.
# Error getting element type for DXC1E: Command: 'pipe ele:head DXC1E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC1E|model": Multiple matches to element: DXC1E. Defaulting to 'Unknown'.
# Element type Unknown for element DXC1E not found in variable configuration mapping. Skipping.
# Error getting element type for D3E: Command: 'pipe ele:head D3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head D3E|model": Multiple matches to element: D3E. Defaulting to 'Unknown'.
# Element type Unknown for element D3E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S1EL not found in variable configuration mapping. Skipping.
# Element type Monitor for element M3E not found in variable configuration mapping. Skipping.
# Error getting element type for DQ3E: Command: 'pipe ele:head DQ3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DQ3E|model": Multiple matches to element: DQ3E. Defaulting to 'Unknown'.
# Element type Unknown for element DQ3E not found in variable configuration mapping. Skipping.
# Element type Monitor for element MS2EL not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S2EL not found in variable configuration mapping. Skipping.
# Error getting element type for DXC2E: Command: 'pipe ele:head DXC2E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC2E|model": Multiple matches to element: DXC2E. Defaulting to 'Unknown'.
# Element type Unknown for element DXC2E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S3EL_1 not found in variable configuration mapping. Skipping.
# Error getting element type for DS3E: Command: 'pipe ele:head DS3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DS3E|model": Multiple matches to element: DS3E. Defaulting to 'Unknown'.
# Element type Unknown for element DS3E not found in variable configuration mapping. Skipping.
# Error getting element type for DQ4E: Command: 'pipe ele:head DQ4E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DQ4E|model": Multiple matches to element: DQ4E. Defaulting to 'Unknown'.
# Element type Unknown for element DQ4E not found in variable configuration mapping. Skipping.
# Element type Monitor for element M4E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S3EL_2 not found in variable configuration mapping. Skipping.
# Error getting element type for DYC2E: Command: 'pipe ele:head DYC2E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC2E|model": Multiple matches to element: DYC2E. Defaulting to 'Unknown'.
# Element type Unknown for element DYC2E not found in variable configuration mapping. Skipping.
# Element type Monitor for element M5E not found in variable configuration mapping. Skipping.
# Element type Monitor for element M6E not found in variable configuration mapping. Skipping.
# Element type Monitor for element M7E not found in variable configuration mapping. Skipping.
# Error getting element type for DYC3E: Command: 'pipe ele:head DYC3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC3E|model": Multiple matches to element: DYC3E. Defaulting to 'Unknown'.
# Element type Unknown for element DYC3E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S3ER_1 not found in variable configuration mapping. Skipping.
# Element type Monitor for element M8E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S3ER_2 not found in variable configuration mapping. Skipping.
# Error getting element type for DXC3E: Command: 'pipe ele:head DXC3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC3E|model": Multiple matches to element: DXC3E. Defaulting to 'Unknown'.
# Element type Unknown for element DXC3E not found in variable configuration mapping. Skipping.
# Element type Monitor for element MS2ER not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S2ER not found in variable configuration mapping. Skipping.
# Element type Monitor for element M9E not found in variable configuration mapping. Skipping.
# Element type Sextupole for element S1ER not found in variable configuration mapping. Skipping.
# Error getting element type for DXC4E: Command: 'pipe ele:head DXC4E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC4E|model": Multiple matches to element: DXC4E. Defaulting to 'Unknown'.
# Element type Unknown for element DXC4E not found in variable configuration mapping. Skipping.
# Error getting element type for DWE: Command: 'pipe ele:head DWE|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DWE|model": Multiple matches to element: DWE. Defaulting to 'Unknown'.
# Element type Unknown for element DWE not found in variable configuration mapping. Skipping.
# Element type Monitor for element SYAG not found in variable configuration mapping. Skipping.
# Element type Monitor for element M11E not found in variable configuration mapping. Skipping.
# Element type Patch for element PATCH_SECTOR20 not found in variable configuration mapping. Skipping.
# Element type Monitor for element M1FF not found in variable configuration mapping. Skipping.
# Element type Monitor for element BL20_4 not found in variable configuration mapping. Skipping.
# Element type Monitor for element M2FF not found in variable configuration mapping. Skipping.
# Element type Monitor for element USTHZ not found in variable configuration mapping. Skipping.
# Element type Monitor for element DSTHZ not found in variable configuration mapping. Skipping.
# Element type Lcavity for element XTCAVF not found in variable configuration mapping. Skipping.
# Element type Monitor for element M3FF not found in variable configuration mapping. Skipping.
# Element type Monitor for element M4FF not found in variable configuration mapping. Skipping.
# Element type Monitor for element M5FF not found in variable configuration mapping. Skipping.
# Element type Monitor for element IPOTR1P not found in variable configuration mapping. Skipping.
# Element type Monitor for element IPWS1 not found in variable configuration mapping. Skipping.
# Element type Monitor for element IPOTR1 not found in variable configuration mapping. Skipping.
# Error getting element type for IPOTR2: Command: 'pipe ele:head IPOTR2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head IPOTR2|model": Multiple matches to element: IPOTR2. Defaulting to 'Unknown'.
# Element type Unknown for element IPOTR2 not found in variable configuration mapping. Skipping.
# Element type Monitor for element IPWS3 not found in variable configuration mapping. Skipping.
# Element type Monitor for element DSOTR not found in variable configuration mapping. Skipping.
# Error getting element type for DM1QEX: Command: 'pipe ele:head DM1QEX|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DM1QEX|model": Multiple matches to element: DM1QEX. Defaulting to 'Unknown'.
# Element type Unknown for element DM1QEX not found in variable configuration mapping. Skipping.
# Element type Monitor for element M0EX not found in variable configuration mapping. Skipping.
# Element type Monitor for element WDSOTR not found in variable configuration mapping. Skipping.
# Element type Monitor for element M1EX not found in variable configuration mapping. Skipping.
# Element type Monitor for element M2EX not found in variable configuration mapping. Skipping.
# Error getting element type for DBPO: Command: 'pipe ele:head DBPO|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBPO|model": Multiple matches to element: DBPO. Defaulting to 'Unknown'.
# Element type Unknown for element DBPO not found in variable configuration mapping. Skipping.
# Error getting element type for DBPI: Command: 'pipe ele:head DBPI|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBPI|model": Multiple matches to element: DBPI. Defaulting to 'Unknown'.
# Element type Unknown for element DBPI not found in variable configuration mapping. Skipping.
# Element type Monitor for element M3EX not found in variable configuration mapping. Skipping.
# Element type Monitor for element DTOTR not found in variable configuration mapping. Skipping.
# Element type Monitor for element PGAM1 not found in variable configuration mapping. Skipping.
# Element type Monitor for element CNEAR not found in variable configuration mapping. Skipping.
# Element type Monitor for element PDUMP not found in variable configuration mapping. Skipping.
# Error getting element type for UM10466: Command: 'pipe ele:head UM10466|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head UM10466|model": Multiple matches to element: UM10466. Defaulting to 'Unknown'.
# Error getting element type for K11_1: Command: 'pipe ele:head K11_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_1|model": Cannot locate element: K11_1. Defaulting to 'Unknown'.
# Error getting element type for DAQ1: Command: 'pipe ele:head DAQ1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ1|model": Multiple matches to element: DAQ1. Defaulting to 'Unknown'.
# Error getting element type for DAQ2: Command: 'pipe ele:head DAQ2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ2|model": Multiple matches to element: DAQ2. Defaulting to 'Unknown'.
# Error getting element type for K11_2: Command: 'pipe ele:head K11_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_2|model": Cannot locate element: K11_2. Defaulting to 'Unknown'.
# Error getting element type for K11_4: Command: 'pipe ele:head K11_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_4|model": Cannot locate element: K11_4. Defaulting to 'Unknown'.
# Error getting element type for DAA7: Command: 'pipe ele:head DAA7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7|model": Multiple matches to element: DAA7. Defaulting to 'Unknown'.
# Error getting element type for DAA7A: Command: 'pipe ele:head DAA7A|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7A|model": Multiple matches to element: DAA7A. Defaulting to 'Unknown'.
# Error getting element type for DAA7B: Command: 'pipe ele:head DAA7B|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7B|model": Multiple matches to element: DAA7B. Defaulting to 'Unknown'.
# Error getting element type for DAA7C: Command: 'pipe ele:head DAA7C|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7C|model": Multiple matches to element: DAA7C. Defaulting to 'Unknown'.
# Error getting element type for K11_5: Command: 'pipe ele:head K11_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_5|model": Cannot locate element: K11_5. Defaulting to 'Unknown'.
# Error getting element type for K11_6: Command: 'pipe ele:head K11_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_6|model": Cannot locate element: K11_6. Defaulting to 'Unknown'.
# Error getting element type for DAA7D: Command: 'pipe ele:head DAA7D|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7D|model": Multiple matches to element: DAA7D. Defaulting to 'Unknown'.
# Error getting element type for DAA7E: Command: 'pipe ele:head DAA7E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAA7E|model": Multiple matches to element: DAA7E. Defaulting to 'Unknown'.
# Error getting element type for K11_7: Command: 'pipe ele:head K11_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_7|model": Cannot locate element: K11_7. Defaulting to 'Unknown'.
# Error getting element type for K11_8: Command: 'pipe ele:head K11_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K11_8|model": Cannot locate element: K11_8. Defaulting to 'Unknown'.
# Error getting element type for DAQ3: Command: 'pipe ele:head DAQ3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ3|model": Multiple matches to element: DAQ3. Defaulting to 'Unknown'.
# Error getting element type for K12_1: Command: 'pipe ele:head K12_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_1|model": Cannot locate element: K12_1. Defaulting to 'Unknown'.
# Error getting element type for K12_2: Command: 'pipe ele:head K12_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_2|model": Cannot locate element: K12_2. Defaulting to 'Unknown'.
# Error getting element type for K12_3: Command: 'pipe ele:head K12_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_3|model": Cannot locate element: K12_3. Defaulting to 'Unknown'.
# Error getting element type for K12_4: Command: 'pipe ele:head K12_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_4|model": Cannot locate element: K12_4. Defaulting to 'Unknown'.
# Error getting element type for K12_5: Command: 'pipe ele:head K12_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_5|model": Cannot locate element: K12_5. Defaulting to 'Unknown'.
# Error getting element type for K12_6: Command: 'pipe ele:head K12_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_6|model": Cannot locate element: K12_6. Defaulting to 'Unknown'.
# Error getting element type for K12_7: Command: 'pipe ele:head K12_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_7|model": Cannot locate element: K12_7. Defaulting to 'Unknown'.
# Error getting element type for K12_8: Command: 'pipe ele:head K12_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K12_8|model": Cannot locate element: K12_8. Defaulting to 'Unknown'.
# Error getting element type for DAQ4: Command: 'pipe ele:head DAQ4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ4|model": Multiple matches to element: DAQ4. Defaulting to 'Unknown'.
# Error getting element type for K13_1: Command: 'pipe ele:head K13_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_1|model": Cannot locate element: K13_1. Defaulting to 'Unknown'.
# Error getting element type for K13_2: Command: 'pipe ele:head K13_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_2|model": Cannot locate element: K13_2. Defaulting to 'Unknown'.
# Error getting element type for K13_3: Command: 'pipe ele:head K13_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_3|model": Cannot locate element: K13_3. Defaulting to 'Unknown'.
# Error getting element type for K13_4: Command: 'pipe ele:head K13_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_4|model": Cannot locate element: K13_4. Defaulting to 'Unknown'.
# Error getting element type for K13_5: Command: 'pipe ele:head K13_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_5|model": Cannot locate element: K13_5. Defaulting to 'Unknown'.
# Error getting element type for K13_6: Command: 'pipe ele:head K13_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_6|model": Cannot locate element: K13_6. Defaulting to 'Unknown'.
# Error getting element type for K13_7: Command: 'pipe ele:head K13_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_7|model": Cannot locate element: K13_7. Defaulting to 'Unknown'.
# Error getting element type for K13_8: Command: 'pipe ele:head K13_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K13_8|model": Cannot locate element: K13_8. Defaulting to 'Unknown'.
# Error getting element type for K14_1: Command: 'pipe ele:head K14_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_1|model": Cannot locate element: K14_1. Defaulting to 'Unknown'.
# Error getting element type for K14_2: Command: 'pipe ele:head K14_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_2|model": Cannot locate element: K14_2. Defaulting to 'Unknown'.
# Error getting element type for K14_3: Command: 'pipe ele:head K14_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_3|model": Cannot locate element: K14_3. Defaulting to 'Unknown'.
# Error getting element type for K14_4: Command: 'pipe ele:head K14_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_4|model": Cannot locate element: K14_4. Defaulting to 'Unknown'.
# Error getting element type for K14_5: Command: 'pipe ele:head K14_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_5|model": Cannot locate element: K14_5. Defaulting to 'Unknown'.
# Error getting element type for K14_6: Command: 'pipe ele:head K14_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K14_6|model": Cannot locate element: K14_6. Defaulting to 'Unknown'.
# Error getting element type for LI14TERM: Command: 'pipe ele:head LI14TERM|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head LI14TERM|model": Multiple matches to element: LI14TERM. Defaulting to 'Unknown'.
# Error getting element type for K15_1: Command: 'pipe ele:head K15_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_1|model": Cannot locate element: K15_1. Defaulting to 'Unknown'.
# Error getting element type for K15_2: Command: 'pipe ele:head K15_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_2|model": Cannot locate element: K15_2. Defaulting to 'Unknown'.
# Error getting element type for K15_3: Command: 'pipe ele:head K15_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_3|model": Cannot locate element: K15_3. Defaulting to 'Unknown'.
# Error getting element type for K15_4: Command: 'pipe ele:head K15_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_4|model": Cannot locate element: K15_4. Defaulting to 'Unknown'.
# Error getting element type for K15_5: Command: 'pipe ele:head K15_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_5|model": Cannot locate element: K15_5. Defaulting to 'Unknown'.
# Error getting element type for K15_6: Command: 'pipe ele:head K15_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_6|model": Cannot locate element: K15_6. Defaulting to 'Unknown'.
# Error getting element type for K15_7: Command: 'pipe ele:head K15_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_7|model": Cannot locate element: K15_7. Defaulting to 'Unknown'.
# Error getting element type for K15_8: Command: 'pipe ele:head K15_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K15_8|model": Cannot locate element: K15_8. Defaulting to 'Unknown'.
# Error getting element type for K16_1: Command: 'pipe ele:head K16_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_1|model": Cannot locate element: K16_1. Defaulting to 'Unknown'.
# Error getting element type for K16_2: Command: 'pipe ele:head K16_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_2|model": Cannot locate element: K16_2. Defaulting to 'Unknown'.
# Error getting element type for K16_3: Command: 'pipe ele:head K16_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_3|model": Cannot locate element: K16_3. Defaulting to 'Unknown'.
# Error getting element type for K16_4: Command: 'pipe ele:head K16_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_4|model": Cannot locate element: K16_4. Defaulting to 'Unknown'.
# Error getting element type for K16_5: Command: 'pipe ele:head K16_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_5|model": Cannot locate element: K16_5. Defaulting to 'Unknown'.
# Error getting element type for K16_6: Command: 'pipe ele:head K16_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_6|model": Cannot locate element: K16_6. Defaulting to 'Unknown'.
# Error getting element type for K16_7: Command: 'pipe ele:head K16_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_7|model": Cannot locate element: K16_7. Defaulting to 'Unknown'.
# Error getting element type for K16_8: Command: 'pipe ele:head K16_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K16_8|model": Cannot locate element: K16_8. Defaulting to 'Unknown'.
# Error getting element type for K17_1: Command: 'pipe ele:head K17_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_1|model": Cannot locate element: K17_1. Defaulting to 'Unknown'.
# Error getting element type for K17_2: Command: 'pipe ele:head K17_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_2|model": Cannot locate element: K17_2. Defaulting to 'Unknown'.
# Error getting element type for K17_3: Command: 'pipe ele:head K17_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_3|model": Cannot locate element: K17_3. Defaulting to 'Unknown'.
# Error getting element type for K17_4: Command: 'pipe ele:head K17_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_4|model": Cannot locate element: K17_4. Defaulting to 'Unknown'.
# Error getting element type for K17_5: Command: 'pipe ele:head K17_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_5|model": Cannot locate element: K17_5. Defaulting to 'Unknown'.
# Error getting element type for K17_6: Command: 'pipe ele:head K17_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_6|model": Cannot locate element: K17_6. Defaulting to 'Unknown'.
# Error getting element type for K17_7: Command: 'pipe ele:head K17_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_7|model": Cannot locate element: K17_7. Defaulting to 'Unknown'.
# Error getting element type for K17_8: Command: 'pipe ele:head K17_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K17_8|model": Cannot locate element: K17_8. Defaulting to 'Unknown'.
# Error getting element type for K18_1: Command: 'pipe ele:head K18_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_1|model": Cannot locate element: K18_1. Defaulting to 'Unknown'.
# Error getting element type for K18_2: Command: 'pipe ele:head K18_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_2|model": Cannot locate element: K18_2. Defaulting to 'Unknown'.
# Error getting element type for K18_3: Command: 'pipe ele:head K18_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_3|model": Cannot locate element: K18_3. Defaulting to 'Unknown'.
# Error getting element type for K18_4: Command: 'pipe ele:head K18_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_4|model": Cannot locate element: K18_4. Defaulting to 'Unknown'.
# Error getting element type for K18_5: Command: 'pipe ele:head K18_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_5|model": Cannot locate element: K18_5. Defaulting to 'Unknown'.
# Error getting element type for K18_6: Command: 'pipe ele:head K18_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_6|model": Cannot locate element: K18_6. Defaulting to 'Unknown'.
# Error getting element type for K18_7: Command: 'pipe ele:head K18_7|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_7|model": Cannot locate element: K18_7. Defaulting to 'Unknown'.
# Error getting element type for K18_8: Command: 'pipe ele:head K18_8|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K18_8|model": Cannot locate element: K18_8. Defaulting to 'Unknown'.
# Error getting element type for K19_1: Command: 'pipe ele:head K19_1|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_1|model": Cannot locate element: K19_1. Defaulting to 'Unknown'.
# Error getting element type for DAQ5A: Command: 'pipe ele:head DAQ5A|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ5A|model": Multiple matches to element: DAQ5A. Defaulting to 'Unknown'.
# Error getting element type for DAQ5B: Command: 'pipe ele:head DAQ5B|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DAQ5B|model": Multiple matches to element: DAQ5B. Defaulting to 'Unknown'.
# Error getting element type for K19_2: Command: 'pipe ele:head K19_2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_2|model": Cannot locate element: K19_2. Defaulting to 'Unknown'.
# Error getting element type for K19_3: Command: 'pipe ele:head K19_3|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_3|model": Cannot locate element: K19_3. Defaulting to 'Unknown'.
# Error getting element type for K19_4: Command: 'pipe ele:head K19_4|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_4|model": Cannot locate element: K19_4. Defaulting to 'Unknown'.
# Error getting element type for DBKY170: Command: 'pipe ele:head DBKY170|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBKY170|model": Multiple matches to element: DBKY170. Defaulting to 'Unknown'.
# Error getting element type for K19_5: Command: 'pipe ele:head K19_5|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_5|model": Cannot locate element: K19_5. Defaulting to 'Unknown'.
# Error getting element type for K19_6: Command: 'pipe ele:head K19_6|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head K19_6|model": Cannot locate element: K19_6. Defaulting to 'Unknown'.
# Error getting element type for D10: Command: 'pipe ele:head D10|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head D10|model": Multiple matches to element: D10. Defaulting to 'Unknown'.
# Error getting element type for DYC1E: Command: 'pipe ele:head DYC1E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC1E|model": Multiple matches to element: DYC1E. Defaulting to 'Unknown'.
# Error getting element type for DXC1E: Command: 'pipe ele:head DXC1E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC1E|model": Multiple matches to element: DXC1E. Defaulting to 'Unknown'.
# Error getting element type for D3E: Command: 'pipe ele:head D3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head D3E|model": Multiple matches to element: D3E. Defaulting to 'Unknown'.
# Error getting element type for DQ3E: Command: 'pipe ele:head DQ3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DQ3E|model": Multiple matches to element: DQ3E. Defaulting to 'Unknown'.
# Error getting element type for DXC2E: Command: 'pipe ele:head DXC2E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC2E|model": Multiple matches to element: DXC2E. Defaulting to 'Unknown'.
# Error getting element type for DS3E: Command: 'pipe ele:head DS3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DS3E|model": Multiple matches to element: DS3E. Defaulting to 'Unknown'.
# Error getting element type for DQ4E: Command: 'pipe ele:head DQ4E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DQ4E|model": Multiple matches to element: DQ4E. Defaulting to 'Unknown'.
# Error getting element type for DYC2E: Command: 'pipe ele:head DYC2E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC2E|model": Multiple matches to element: DYC2E. Defaulting to 'Unknown'.
# Error getting element type for DYC3E: Command: 'pipe ele:head DYC3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DYC3E|model": Multiple matches to element: DYC3E. Defaulting to 'Unknown'.
# Error getting element type for DXC3E: Command: 'pipe ele:head DXC3E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC3E|model": Multiple matches to element: DXC3E. Defaulting to 'Unknown'.
# Error getting element type for DXC4E: Command: 'pipe ele:head DXC4E|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DXC4E|model": Multiple matches to element: DXC4E. Defaulting to 'Unknown'.
# Error getting element type for DWE: Command: 'pipe ele:head DWE|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DWE|model": Multiple matches to element: DWE. Defaulting to 'Unknown'.
# Error getting element type for IPOTR2: Command: 'pipe ele:head IPOTR2|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head IPOTR2|model": Multiple matches to element: IPOTR2. Defaulting to 'Unknown'.
# Error getting element type for DM1QEX: Command: 'pipe ele:head DM1QEX|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DM1QEX|model": Multiple matches to element: DM1QEX. Defaulting to 'Unknown'.
# Error getting element type for DBPO: Command: 'pipe ele:head DBPO|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBPO|model": Multiple matches to element: DBPO. Defaulting to 'Unknown'.
# Error getting element type for DBPI: Command: 'pipe ele:head DBPI|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head DBPI|model": Multiple matches to element: DBPI. Defaulting to 'Unknown'.
# Warning: track_start is set to PR10241, which is not the first element in the lattice FIXER_INJ. This may lead to unexpected behavior if the initial particles are not properly initialized at the track_start element.
# /mnt/c/Users/Ryan Roussel/Documents/GitHub/virtual-accelerator/virtual_accelerator/bmad/factory.py:115: UserWarning: track_beam=True for start_element != L0AFEND without providing custom_beam_path
#   warnings.warn(

# %%
# plot the staged model
info = staged_model.get(
    [
        "s",
        "s_ele",
        "p0c",
        "stat:mean_z",
        "stat:mean_kinetic_energy",
        "stat:norm_emit_x",
        "x.norm_emit",
        "stat:",
    ]
)

fig, ax = plt.subplots(2, 1, sharex=True)

ax[0].plot(info["s_ele"], info["p0c"])
ax[0].plot(info["stat:mean_z"], info["stat:mean_kinetic_energy"])
ax[0].set_ylabel("Kinetic Energy")
ax[1].plot(info["s"], info["x.norm_emit"], label="Bmad")
ax[1].plot(info["stat:mean_z"], info["stat:norm_emit_x"], label="Impact")
ax[1].set_xlabel("s")
ax[1].set_ylabel("Normalized Emittance x")
ax[1].legend()

# %%
import numpy as np

s_tot = np.append(staged_model.get("stat:mean_z"), staged_model.get("s"))
rms_x = np.append(
    staged_model.get("stat:sigma_x"),
    (staged_model.get("x.emit") * staged_model.get("x.beta")) ** 0.5,
)
rms_y = np.append(
    staged_model.get("stat:sigma_y"),
    (staged_model.get("y.emit") * staged_model.get("y.beta")) ** 0.5,
)
plt.plot(s_tot, rms_x, label="RMS X")
plt.plot(s_tot, rms_y, label="RMS Y")
plt.legend()
plt.xlim(0, 30)
plt.xlabel("s")
plt.ylabel("RMS Beam Size")
# Out:
# Text(0, 0.5, 'RMS Beam Size')
