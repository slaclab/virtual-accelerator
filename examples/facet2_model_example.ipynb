# %%
from virtual_accelerator.models.facet2 import get_facet_bmad_model

model = get_facet_bmad_model(
    track_beam=False,
    start_element="L0AFEND",
    end_element="PR10711",
)
# Out:
# Element type Lcavity for element L0BF not found in variable configuration mapping. Skipping.
# Element type SBend for element BCX10451 not found in variable configuration mapping. Skipping.
# Element type SBend for element BCX10461 not found in variable configuration mapping. Skipping.
# Screen PR10465 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Error getting element type for UM10466: Command: 'pipe ele:head UM10466|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head UM10466|model": Multiple matches to element: UM10466. Defaulting to 'Unknown'.
# More than one element found matching 'UM10466'. Returning the first one. To suppress this, use `warn=False`.
# Element type Unknown for element UM10466 not found in variable configuration mapping. Skipping.
# Screen PR10471 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type SBend for element BCX10475 not found in variable configuration mapping. Skipping.
# Element type SBend for element BCX10481 not found in variable configuration mapping. Skipping.
# Element type Lcavity for element TCY10490 not found in variable configuration mapping. Skipping.
# Element type Monitor for element BZ10596 not found in variable configuration mapping. Skipping.
# Element type SBend for element BX10661 not found in variable configuration mapping. Skipping.
# Error getting element type for UM10466: Command: 'pipe ele:head UM10466|model' causes errors in the function(s): tao_pipe_cmd
#
# Error in tao_pipe_cmd:
#   "pipe ele:head UM10466|model": Multiple matches to element: UM10466. Defaulting to 'Unknown'.

# %%
model.get("KLYS:LI10:41:SFB_PDES")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.get("KLYS:LI10:41:SFB_PDES")
#
# File /mnt/c/Users/Ryan Roussel/Documents/GitHub/lume-base/lume/model.py:60, in LUMEModel.get(self, names)
#      58 for name in names:
#      59     if name not in self.supported_variables:
# ---> 60         raise ValueError(f"Variable '{name}' is not supported by the model.")
#      62 outputs = self._get(names)
#      64 # Validate outputs
#
# ValueError: Variable 'KLYS:LI10:41:SFB_PDES' is not supported by the model.

# %%
variable_names = list(model.supported_variables.keys())
print(f"Supported variables: {len(variable_names)}")
print("Example variable names:")
print(variable_names[:10])

# %% [markdown]
# ## Predictions at elements

# %%
import matplotlib.pyplot as plt

out = model.get(["s_ele", "a.beta", "b.beta", "e_tot"])
plt.plot(out["s_ele"], out["e_tot"] / 1e6, label="b")
plt.ylabel("Total energy (MeV)")
plt.xlabel("s (m)")

plt.figure()
plt.plot(out["s_ele"], out["a.beta"], label="a.beta")
plt.plot(out["s_ele"], out["b.beta"], label="b.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()

# %% [markdown]
# ## Predictions using comb

# %%
import matplotlib.pyplot as plt

out = model.get(["s", "x.beta", "y.beta"])

plt.figure()
plt.plot(out["s"], out["x.beta"], label="x.beta")
plt.plot(out["s"], out["y.beta"], label="y.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()

# %% [markdown]
# ## Staged FACET-II model

# %%
from virtual_accelerator.models.facet2 import get_facet_staged_model

staged_model = get_facet_staged_model(
    surrogate_inputs="machine", n_particles=1000, end_element="PR10711"
)

# %%
out = staged_model.get(["s", "x.beta", "y.beta", "s_ele", "a.beta", "b.beta"])
plt.plot(out["s"], out["x.beta"], label="tracked x.beta")
plt.plot(out["s"], out["y.beta"], label="tracked y.beta")
plt.plot(out["s_ele"], out["a.beta"], "--", label="design a.beta")
plt.plot(out["s_ele"], out["b.beta"], "--", label="design b.beta")
plt.xlabel("s (m)")
plt.ylabel("Beta function")
plt.legend()
